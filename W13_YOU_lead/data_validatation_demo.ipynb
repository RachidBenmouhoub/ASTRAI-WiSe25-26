# %%
import pandas as pd

# %%
data = {
"speed": [50, -15, 180, None, 70],
"vehicle_count": [120, 90, 60, 110, -5]
}
df = pd.DataFrame(data)

# %%
df

# %%
print(df)

# %%
df[df["speed"] < 0]

# %%
df[df["speed"] > 130]

# %%
df.isnull().sum()

# %%
df_valid= df[(df["speed"] >= 0) & (df["speed"] <= 130)]
df_valid

# %%
df_valid["vehicle_count"] = df_valid["vehicle_count"].clip(lower=0)
df_valid
